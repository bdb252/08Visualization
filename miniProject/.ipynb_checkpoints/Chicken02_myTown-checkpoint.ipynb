# %%
import squarify
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
# 한글깨짐처리를 위해 폰트매니저 임포트
font_path='../resData/malgun.ttf'
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
df = pd.read_excel('../resData/서울특별시_일반음식점.xlsx', engine='openpyxl', 
                   usecols=['소재지전체주소','업태구분명'])

find_str = '종로구'

mask = (
    df['소재지전체주소'].str.contains(find_str, na=False)  & 
    ((df['업태구분명'] == '통닭(치킨)') | (df['업태구분명'] == '호프/통닭'))
)
df_jongro = df[mask]
# print(df_jongro.head())
print(df_jongro)
# Out:
# C:\01DevelopKits\miniconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                           소재지전체주소   업태구분명
# 13        서울특별시 종로구 낙원동 198 금강빌딩    호프/통닭
# 19            서울특별시 종로구 명륜2가 184    호프/통닭
# 57           서울특별시 종로구 명륜4가 11-2    호프/통닭
# 58          서울특별시 종로구 종로3가 132-1    호프/통닭
# 87     서울특별시 종로구 무악동 89 경희궁 롯데캐슬    호프/통닭
# ...                           ...     ...
# 19841      서울특별시 종로구 소격동 144-6번지    호프/통닭
# 19843       서울특별시 종로구 명륜2가 184번지   통닭(치킨)
# 19873         서울특별시 종로구 통인동 94-1    호프/통닭
# 19885          서울특별시 종로구 낙원동 232    호프/통닭
# 19977       서울특별시 종로구 창신동 438-14    호프/통닭
#
# [563 rows x 2 columns]

# %%
df_jongro['dong_nm']=df_jongro['소재지전체주소'].str.split().str[2]
# df_jongro.columns=['addr1', 'addr2', 'menutype']
print(df_jongro)
# Out:
#                           소재지전체주소   업태구분명 dong_nm
# 13        서울특별시 종로구 낙원동 198 금강빌딩    호프/통닭     낙원동
# 19            서울특별시 종로구 명륜2가 184    호프/통닭    명륜2가
# 57           서울특별시 종로구 명륜4가 11-2    호프/통닭    명륜4가
# 58          서울특별시 종로구 종로3가 132-1    호프/통닭    종로3가
# 87     서울특별시 종로구 무악동 89 경희궁 롯데캐슬    호프/통닭     무악동
# ...                           ...     ...     ...
# 19841      서울특별시 종로구 소격동 144-6번지    호프/통닭     소격동
# 19843       서울특별시 종로구 명륜2가 184번지   통닭(치킨)    명륜2가
# 19873         서울특별시 종로구 통인동 94-1    호프/통닭     통인동
# 19885          서울특별시 종로구 낙원동 232    호프/통닭     낙원동
# 19977       서울특별시 종로구 창신동 438-14    호프/통닭     창신동
#
# [563 rows x 3 columns]
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_1348\2812400201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jongro['dong_nm']=df_jongro['소재지전체주소'].str.split().str[2]

# %%
df_jongro.to_csv('../saveFiles/치킨집가공.csv')

# %%
df_chicken = pd.read_csv('../saveFiles/치킨집가공.csv')
df_chicken
# Out:
#      Unnamed: 0                     소재지전체주소   업태구분명 dong_nm
# 0            13     서울특별시 종로구 낙원동 198 금강빌딩    호프/통닭     낙원동
# 1            19         서울특별시 종로구 명륜2가 184    호프/통닭    명륜2가
# 2            57        서울특별시 종로구 명륜4가 11-2    호프/통닭    명륜4가
# 3            58       서울특별시 종로구 종로3가 132-1    호프/통닭    종로3가
# 4            87  서울특별시 종로구 무악동 89 경희궁 롯데캐슬    호프/통닭     무악동
# ..          ...                         ...     ...     ...
# 558       19841      서울특별시 종로구 소격동 144-6번지    호프/통닭     소격동
# 559       19843       서울특별시 종로구 명륜2가 184번지   통닭(치킨)    명륜2가
# 560       19873         서울특별시 종로구 통인동 94-1    호프/통닭     통인동
# 561       19885          서울특별시 종로구 낙원동 232    호프/통닭     낙원동
# 562       19977       서울특별시 종로구 창신동 438-14    호프/통닭     창신동
#
# [563 rows x 4 columns]

# %%
df_chicken['dong_nm'].value_counts()
# Out:
# dong_nm
# 창신동     68
# 관철동     57
# 숭인동     52
# 명륜2가    29
# 동숭동     28
#         ..
# 삼청동      1
# 팔판동      1
# 창성동      1
# 중학동      1
# 소격동      1
# Name: count, Length: 70, dtype: int64

# %%
dong_count = df_chicken['dong_nm'].value_counts().to_frame()
dong_count
# Out:
#          count
# dong_nm
# 창신동         68
# 관철동         57
# 숭인동         52
# 명륜2가        29
# 동숭동         28
# ...        ...
# 삼청동          1
# 팔판동          1
# 창성동          1
# 중학동          1
# 소격동          1
#
# [70 rows x 1 columns]

# %%
dong_count = dong_count.reset_index().rename(columns={"index":"dong_nm","count":"count"})
dong_count
# Out:
#    dong_nm  count
# 0      창신동     68
# 1      관철동     57
# 2      숭인동     52
# 3     명륜2가     29
# 4      동숭동     28
# ..     ...    ...
# 65     삼청동      1
# 66     팔판동      1
# 67     창성동      1
# 68     중학동      1
# 69     소격동      1
#
# [70 rows x 2 columns]

# %%
import squarify
plt.style.use('ggplot')
font_name=(font_manager.FontProperties(fname='../resData/malgun.ttf').get_name())
rc('font', family=font_name)

dong_count['label'] = dong_count['dong_nm'] + '('+dong_count['count'].astype(str) + ')'
squarify.plot(sizes=dong_count['count'], label=dong_count['label'], alpha=0.8)
plt.axis('off')
plt.show()
